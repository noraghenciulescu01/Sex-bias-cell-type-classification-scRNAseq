# %%
import pyreadr
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Define paths:

# %%
# this is the dataframe resulting from the analysis of individual classification trends:
path_classif_df = 'C:/Users/SG/Sex-bias-cell-type-classification-scRNAseq/3. HLCA core - analysis of classification results/Analysis_results/df_classification_trend.pickle'

# this is the dictionary of cell type info resulting from the exploration + DA analysis
path_cell_type_info = 'C:/Users/SG/Sex-bias-cell-type-classification-scRNAseq/1. HLCA core - exploration/DA_results/cell_type_info_with_DA.pickle'

# %% [markdown]
# #### Import data

# %% [markdown]
# Import the DS results:

# %%
result = pyreadr.read_r("final_DS_results.rds")
df_DS = result[None]
df_DS
# Out:
#                                 #DS    %DS
# rownames
# Basal resting                 142.0   0.71
# Multiciliated (non-nasal)      42.0  0.208
# Alveolar macrophages           33.0  0.164
# EC arterial                    29.0  0.154
# Suprabasal                     19.0  0.094
# ...                             ...    ...
# Lymphatic EC proliferating      NaN    NaN
# Lymphatic EC differentiating    NaN    NaN
# Subpleural fibroblasts          NaN    NaN
# Mesothelium                     NaN    NaN
# Hematopoietic stem cells        NaN    NaN
#
# [61 rows x 2 columns]

# %% [markdown]
# Import the misclassification results:

# %%
with open(path_classif_df, 'rb') as file:
    df_classification_trend = pickle.load(file)
df_classification_trend.sort_values('Classification trend')
# Out:
#                    Cell type Slope test Flip test  \
# 0                        AT0       True      True
# 44   Non-classical monocytes       True      True
# 41            Myofibroblasts       True      True
# 39     Multiciliated (nasal)       True      True
# 38      Monocyte-derived Mph       True      True
# ..                       ...        ...       ...
# 8       Alveolar fibroblasts      False      True
# 6   Alveolar Mph MT-positive      False     False
# 4    Adventitial fibroblasts      False      True
# 37             Migratory DCs      False     False
# 60          pre-TB secretory      False     False
#
#     Maximum performance difference  Slope on female set  Slope on male set  \
# 0                         0.311030             0.154401          -0.107692
# 44                        0.181524             0.020268          -0.150805
# 41                        0.223347             0.244085          -0.077075
# 39                        0.361397             0.250057          -0.161455
# 38                        0.258688             0.149452          -0.169069
# ..                             ...                  ...                ...
# 8                         0.151723             0.145536           0.012718
# 6                         0.420814             0.596874           0.867133
# 4                         0.084243            -0.034711          -0.100552
# 37                        0.145963            -0.058442          -0.023715
# 60                        0.283976            -0.115530          -0.337315
#
#    Classification trend
# 0              Distinct
# 44             Distinct
# 41             Distinct
# 39             Distinct
# 38             Distinct
# ..                  ...
# 8          Non-distinct
# 6          Non-distinct
# 4          Non-distinct
# 37         Non-distinct
# 60         Non-distinct
#
# [61 rows x 7 columns]

# %% [markdown]
# #### Combine results

# %%
for i in df_DS.index:
    if i in list(df_classification_trend["Cell type"]):
        df_DS.loc[i, "Classification trend"] = df_classification_trend.loc[df_classification_trend['Cell type'] == i,'Classification trend'].iloc[0]
    else:
        print(f'{i} not in misclassification analysis')

# round %DS for readability
def round_numeric(val, decimals=4):
    try:
        return round(float(val), decimals)
    except (ValueError, TypeError):
        return val
df_DS['%DS'] = df_DS['%DS'].apply(round_numeric)

# replace NaNs
df_DS.replace('NaN', '-', inplace=True)
df_DS.replace(float('nan'), '-', inplace=True)

# reformat table
df_DS.reset_index(inplace = True)
df_DS.rename(columns={'rownames': 'Cell type'}, inplace=True)
df_DS = df_DS[['Cell type', '#DS', '%DS', 'Classification trend']]

# make #DS an int for readability
def toint_numeric(val):
    try:
        return int(val)
    except (ValueError, TypeError):
        return val
df_DS['#DS'] = df_DS['#DS'].apply(toint_numeric)

# show table
df_DS.head(60)
# Out:
#                         Cell type  #DS     %DS Classification trend
# 0                   Basal resting  142    0.71         Inconclusive
# 1       Multiciliated (non-nasal)   42   0.208         Inconclusive
# 2            Alveolar macrophages   33   0.164             Distinct
# 3                     EC arterial   29   0.154             Distinct
# 4                      Suprabasal   19   0.094             Distinct
# 5                             AT2   15  0.0744         Inconclusive
# 6                  Goblet (nasal)   12  0.0601             Distinct
# 7                    Club (nasal)   11  0.0557             Distinct
# 8             EC venous pulmonary   10  0.0536             Distinct
# 9              Goblet (bronchial)    9  0.0482             Distinct
# 10          Multiciliated (nasal)    9  0.0475             Distinct
# 11            Classical monocytes    8   0.041             Distinct
# 12                            DC2    8  0.0409         Non-distinct
# 13           Monocyte-derived Mph    8  0.0405             Distinct
# 14        Non-classical monocytes    7  0.0369             Distinct
# 15               Club (non-nasal)    7  0.0356             Distinct
# 16                    CD8 T cells    7  0.0355         Non-distinct
# 17  Interstitial Mph perivascular    5  0.0272         Non-distinct
# 18                       NK cells    5  0.0264         Inconclusive
# 19             EC venous systemic    5  0.0262         Inconclusive
# 20                    CD4 T cells    5  0.0258         Non-distinct
# 21        Adventitial fibroblasts    5  0.0253         Non-distinct
# 22     Alveolar Mph proliferating    4  0.0225             Distinct
# 23                            AT0    4  0.0221             Distinct
# 24                   Plasma cells    4   0.022         Inconclusive
# 25                   Deuterosomal    4  0.0215             Distinct
# 26                     Mast cells    4  0.0214         Inconclusive
# 27          T cells proliferating    3  0.0186         Non-distinct
# 28                       Ionocyte    3  0.0171         Inconclusive
# 29              AT2 proliferating    3  0.0168             Distinct
# 30            Lymphatic EC mature    3  0.0162         Inconclusive
# 31             Alveolar Mph CCL3+    3  0.0158             Distinct
# 32               pre-TB secretory    3  0.0155         Non-distinct
# 33          Smooth muscle FAM83D+    2  0.0142         Non-distinct
# 34                  Migratory DCs    2  0.0133         Non-distinct
# 35               Plasmacytoid DCs    2  0.0132         Non-distinct
# 36                 Myofibroblasts    2   0.012             Distinct
# 37                      Pericytes    2  0.0114         Inconclusive
# 38      Peribronchial fibroblasts    2   0.011             Distinct
# 39                        B cells    2  0.0109         Inconclusive
# 40                       SMG duct    2  0.0107         Non-distinct
# 41                            AT1    2  0.0107         Inconclusive
# 42                            DC1    1  0.0065         Non-distinct
# 43       Alveolar Mph MT-positive    1  0.0063         Non-distinct
# 44                     SMG mucous    1  0.0062         Inconclusive
# 45         SMG serous (bronchial)    1  0.0059         Non-distinct
# 46   SM activated stress response    1  0.0059             Distinct
# 47          EC aerocyte capillary    1  0.0055         Inconclusive
# 48                  Smooth muscle    1  0.0054         Inconclusive
# 49           EC general capillary    1  0.0053             Distinct
# 50           Alveolar fibroblasts    1  0.0052         Non-distinct
# 51                   Hillock-like    0     0.0             Distinct
# 52                           Tuft    0     0.0         Non-distinct
# 53                 Neuroendocrine    0     0.0         Inconclusive
# 54          Goblet (subsegmental)    -       -             Distinct
# 55             SMG serous (nasal)    -       -         Non-distinct
# 56     Lymphatic EC proliferating    -       -         Inconclusive
# 57   Lymphatic EC differentiating    -       -         Non-distinct
# 58         Subpleural fibroblasts    -       -             Distinct
# 59                    Mesothelium    -       -         Non-distinct

# %% [markdown]
# #### Rank sum test to check if distinct cell types are more DE

# %%
from scipy.stats import mannwhitneyu

df_totest = df_DS[(df_DS["#DS"] != '-') & (df_DS["Classification trend"] != 'Inconclusive')]
df_totest['%DS'] = pd.to_numeric(df_totest['%DS'])

distinct = df_totest.loc[df_totest["Classification trend"] == 'Distinct','%DS']
nondistinct = df_totest.loc[df_totest["Classification trend"] == 'Non-distinct','%DS']

# perform the Mann-Whitney U test
stat, p_value = mannwhitneyu(distinct, nondistinct, alternative='greater')
stat, p_value
# Out:
# C:\Users\SG\AppData\Local\Temp\ipykernel_16168\1422442394.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totest['%DS'] = pd.to_numeric(df_totest['%DS'])
# (259.0, 0.007355214506687283)

# %% [markdown]
# p-value of 0.00735 --> significant correlation

# %% [markdown]
# #### Add data on sex ratio & DA

# %% [markdown]
# Import additional information:

# %%
# import data on sample counts, donor counts etc
with open(path_cell_type_info, 'rb') as file:
    cell_type_info = pickle.load(file)
cell_type_info
# Out:
# {'Basal resting': {'total_samples': 38955,
#   'female_prop': 0.3647028622769863,
#   'num_donors': 77,
#   'num_female_donors': 33,
#   'num_DA_nhoods': 1546,
#   'prop_DA_nhoods': 0.58},
#  'Suprabasal': {'total_samples': 41158,
#   'female_prop': 0.4482482141989407,
#   'num_donors': 77,
#   'num_female_donors': 32,
#   'num_DA_nhoods': 1906,
#   'prop_DA_nhoods': 0.67},
#  'Hillock-like': {'total_samples': 4600,
#   'female_prop': 0.538695652173913,
#   'num_donors': 38,
#   'num_female_donors': 15,
#   'num_DA_nhoods': 202,
#   'prop_DA_nhoods': 0.65},
#  'Deuterosomal': {'total_samples': 1004,
#   'female_prop': 0.4312749003984064,
#   'num_donors': 70,
#   'num_female_donors': 28,
#   'num_DA_nhoods': 1,
#   'prop_DA_nhoods': 0.01},
#  'Multiciliated (nasal)': {'total_samples': 4869,
#   'female_prop': 0.4113781063873485,
#   'num_donors': 37,
#   'num_female_donors': 16,
#   'num_DA_nhoods': 212,
#   'prop_DA_nhoods': 0.66},
#  'Multiciliated (non-nasal)': {'total_samples': 35225,
#   'female_prop': 0.352278211497516,
#   'num_donors': 102,
#   'num_female_donors': 37,
#   'num_DA_nhoods': 938,
#   'prop_DA_nhoods': 0.38},
#  'Club (non-nasal)': {'total_samples': 9955,
#   'female_prop': 0.4677046710195881,
#   'num_donors': 73,
#   'num_female_donors': 26,
#   'num_DA_nhoods': 403,
#   'prop_DA_nhoods': 0.59},
#  'Club (nasal)': {'total_samples': 26068,
#   'female_prop': 0.49827374558846094,
#   'num_donors': 54,
#   'num_female_donors': 23,
#   'num_DA_nhoods': 878,
#   'prop_DA_nhoods': 0.48},
#  'Goblet (nasal)': {'total_samples': 35833,
#   'female_prop': 0.5487678955153071,
#   'num_donors': 75,
#   'num_female_donors': 29,
#   'num_DA_nhoods': 1409,
#   'prop_DA_nhoods': 0.57},
#  'Goblet (bronchial)': {'total_samples': 1670,
#   'female_prop': 0.3119760479041916,
#   'num_donors': 54,
#   'num_female_donors': 21,
#   'num_DA_nhoods': 87,
#   'prop_DA_nhoods': 0.79},
#  'Goblet (subsegmental)': {'total_samples': 968,
#   'female_prop': 0.45454545454545453,
#   'num_donors': 32,
#   'num_female_donors': 18,
#   'num_DA_nhoods': 31,
#   'prop_DA_nhoods': 0.52},
#  'AT0': {'total_samples': 1440,
#   'female_prop': 0.6555555555555556,
#   'num_donors': 57,
#   'num_female_donors': 19,
#   'num_DA_nhoods': 52,
#   'prop_DA_nhoods': 0.69},
#  'pre-TB secretory': {'total_samples': 4393,
#   'female_prop': 0.2185294787161393,
#   'num_donors': 88,
#   'num_female_donors': 32,
#   'num_DA_nhoods': 110,
#   'prop_DA_nhoods': 0.38},
#  'Ionocyte': {'total_samples': 561,
#   'female_prop': 0.3511586452762923,
#   'num_donors': 50,
#   'num_female_donors': 20,
#   'num_DA_nhoods': 3,
#   'prop_DA_nhoods': 0.08},
#  'Tuft': {'total_samples': 165,
#   'female_prop': 0.3333333333333333,
#   'num_donors': 30,
#   'num_female_donors': 13,
#   'num_DA_nhoods': 0,
#   'prop_DA_nhoods': 0.0},
#  'Neuroendocrine': {'total_samples': 159,
#   'female_prop': 0.4591194968553459,
#   'num_donors': 36,
#   'num_female_donors': 15,
#   'num_DA_nhoods': 0,
#   'prop_DA_nhoods': 0.0},
#  'SMG serous (nasal)': {'total_samples': 1472,
#   'female_prop': 0.7574728260869565,
#   'num_donors': 9,
#   'num_female_donors': 4,
#   'num_DA_nhoods': 94,
#   'prop_DA_nhoods': 0.8},
#  'SMG serous (bronchial)': {'total_samples': 1417,
#   'female_prop': 0.20606916019760058,
#   'num_donors': 21,
#   'num_female_donors': 8,
#   'num_DA_nhoods': 46,
#   'prop_DA_nhoods': 0.44},
#  'SMG mucous': {'total_samples': 537,
#   'female_prop': 0.40409683426443205,
#   'num_donors': 19,
#   'num_female_donors': 7,
#   'num_DA_nhoods': 13,
#   'prop_DA_nhoods': 0.36},
#  'SMG duct': {'total_samples': 1274,
#   'female_prop': 0.30847723704866564,
#   'num_donors': 43,
#   'num_female_donors': 17,
#   'num_DA_nhoods': 12,
#   'prop_DA_nhoods': 0.14},
#  'AT1': {'total_samples': 7937,
#   'female_prop': 0.3930956280710596,
#   'num_donors': 65,
#   'num_female_donors': 22,
#   'num_DA_nhoods': 164,
#   'prop_DA_nhoods': 0.3},
#  'AT2': {'total_samples': 61429,
#   'female_prop': 0.4942291100294649,
#   'num_donors': 73,
#   'num_female_donors': 23,
#   'num_DA_nhoods': 3174,
#   'prop_DA_nhoods': 0.77},
#  'AT2 proliferating': {'total_samples': 976,
#   'female_prop': 0.6577868852459017,
#   'num_donors': 49,
#   'num_female_donors': 18,
#   'num_DA_nhoods': 35,
#   'prop_DA_nhoods': 0.53},
#  'EC arterial': {'total_samples': 7391,
#   'female_prop': 0.2099851170342308,
#   'num_donors': 77,
#   'num_female_donors': 25,
#   'num_DA_nhoods': 204,
#   'prop_DA_nhoods': 0.4},
#  'EC aerocyte capillary': {'total_samples': 7157,
#   'female_prop': 0.17884588514740812,
#   'num_donors': 47,
#   'num_female_donors': 15,
#   'num_DA_nhoods': 335,
#   'prop_DA_nhoods': 0.66},
#  'EC general capillary': {'total_samples': 16048,
#   'female_prop': 0.19659770687936193,
#   'num_donors': 69,
#   'num_female_donors': 20,
#   'num_DA_nhoods': 612,
#   'prop_DA_nhoods': 0.54},
#  'EC venous systemic': {'total_samples': 6557,
#   'female_prop': 0.44913832545371357,
#   'num_donors': 75,
#   'num_female_donors': 26,
#   'num_DA_nhoods': 189,
#   'prop_DA_nhoods': 0.41},
#  'EC venous pulmonary': {'total_samples': 6418,
#   'female_prop': 0.20255531318167652,
#   'num_donors': 71,
#   'num_female_donors': 23,
#   'num_DA_nhoods': 164,
#   'prop_DA_nhoods': 0.37},
#  'Lymphatic EC mature': {'total_samples': 4001,
#   'female_prop': 0.2554361409647588,
#   'num_donors': 69,
#   'num_female_donors': 22,
#   'num_DA_nhoods': 87,
#   'prop_DA_nhoods': 0.32},
#  'Lymphatic EC proliferating': {'total_samples': 28,
#   'female_prop': 0.2857142857142857,
#   'num_donors': 10,
#   'num_female_donors': 4,
#   'num_DA_nhoods': 0,
#   'prop_DA_nhoods': 0.0},
#  'Lymphatic EC differentiating': {'total_samples': 566,
#   'female_prop': 0.061837455830388695,
#   'num_donors': 36,
#   'num_female_donors': 10,
#   'num_DA_nhoods': 14,
#   'prop_DA_nhoods': 0.52},
#  'Peribronchial fibroblasts': {'total_samples': 1573,
#   'female_prop': 0.3172282263191354,
#   'num_donors': 59,
#   'num_female_donors': 19,
#   'num_DA_nhoods': 23,
#   'prop_DA_nhoods': 0.21},
#  'Adventitial fibroblasts': {'total_samples': 10321,
#   'female_prop': 0.13332041468849917,
#   'num_donors': 73,
#   'num_female_donors': 23,
#   'num_DA_nhoods': 589,
#   'prop_DA_nhoods': 0.77},
#  'Alveolar fibroblasts': {'total_samples': 5182,
#   'female_prop': 0.42994982632188344,
#   'num_donors': 64,
#   'num_female_donors': 19,
#   'num_DA_nhoods': 156,
#   'prop_DA_nhoods': 0.42},
#  'Pericytes': {'total_samples': 3032,
#   'female_prop': 0.19063324538258575,
#   'num_donors': 38,
#   'num_female_donors': 9,
#   'num_DA_nhoods': 108,
#   'prop_DA_nhoods': 0.55},
#  'Subpleural fibroblasts': {'total_samples': 276,
#   'female_prop': 0.3188405797101449,
#   'num_donors': 17,
#   'num_female_donors': 6,
#   'num_DA_nhoods': 13,
#   'prop_DA_nhoods': 0.68},
#  'Myofibroblasts': {'total_samples': 716,
#   'female_prop': 0.5083798882681564,
#   'num_donors': 41,
#   'num_female_donors': 14,
#   'num_DA_nhoods': 28,
#   'prop_DA_nhoods': 0.51},
#  'Smooth muscle': {'total_samples': 2996,
#   'female_prop': 0.47096128170894525,
#   'num_donors': 74,
#   'num_female_donors': 26,
#   'num_DA_nhoods': 47,
#   'prop_DA_nhoods': 0.21},
#  'Smooth muscle FAM83D+': {'total_samples': 335,
#   'female_prop': 0.764179104477612,
#   'num_donors': 23,
#   'num_female_donors': 12,
#   'num_DA_nhoods': 13,
#   'prop_DA_nhoods': 0.48},
#  'SM activated stress response': {'total_samples': 556,
#   'female_prop': 0.2733812949640288,
#   'num_donors': 21,
#   'num_female_donors': 6,
#   'num_DA_nhoods': 17,
#   'prop_DA_nhoods': 0.46},
#  'Mesothelium': {'total_samples': 230,
#   'female_prop': 0.030434782608695653,
#   'num_donors': 21,
#   'num_female_donors': 4,
#   'num_DA_nhoods': 13,
#   'prop_DA_nhoods': 0.93},
#  'Hematopoietic stem cells': {'total_samples': 60,
#   'female_prop': 0.6833333333333333,
#   'num_donors': 22,
#   'num_female_donors': 10,
#   'num_DA_nhoods': 0,
#   'prop_DA_nhoods': 0.0},
#  'B cells': {'total_samples': 4511,
#   'female_prop': 0.36333407226778985,
#   'num_donors': 77,
#   'num_female_donors': 28,
#   'num_DA_nhoods': 107,
#   'prop_DA_nhoods': 0.37},
#  'Plasma cells': {'total_samples': 1773,
#   'female_prop': 0.5002820078962211,
#   'num_donors': 70,
#   'num_female_donors': 22,
#   'num_DA_nhoods': 33,
#   'prop_DA_nhoods': 0.26},
#  'CD4 T cells': {'total_samples': 21285,
#   'female_prop': 0.56805261921541,
#   'num_donors': 88,
#   'num_female_donors': 29,
#   'num_DA_nhoods': 652,
#   'prop_DA_nhoods': 0.47},
#  'CD8 T cells': {'total_samples': 29074,
#   'female_prop': 0.38866341060741555,
#   'num_donors': 86,
#   'num_female_donors': 30,
#   'num_DA_nhoods': 781,
#   'prop_DA_nhoods': 0.4},
#  'T cells proliferating': {'total_samples': 500,
#   'female_prop': 0.756,
#   'num_donors': 49,
#   'num_female_donors': 18,
#   'num_DA_nhoods': 18,
#   'prop_DA_nhoods': 0.53},
#  'NK cells': {'total_samples': 16978,
#   'female_prop': 0.5925904111202733,
#   'num_donors': 74,
#   'num_female_donors': 25,
#   'num_DA_nhoods': 550,
#   'prop_DA_nhoods': 0.48},
#  'DC1': {'total_samples': 322,
#   'female_prop': 0.5093167701863354,
#   'num_donors': 53,
#   'num_female_donors': 17,
#   'num_DA_nhoods': 0,
#   'prop_DA_nhoods': 0.0},
#  'DC2': {'total_samples': 9133,
#   'female_prop': 0.426146939669331,
#   'num_donors': 91,
#   'num_female_donors': 30,
#   'num_DA_nhoods': 162,
#   'prop_DA_nhoods': 0.28},
#  'Migratory DCs': {'total_samples': 312,
#   'female_prop': 0.44551282051282054,
#   'num_donors': 53,
#   'num_female_donors': 15,
#   'num_DA_nhoods': 2,
#   'prop_DA_nhoods': 0.09},
#  'Plasmacytoid DCs': {'total_samples': 552,
#   'female_prop': 0.3007246376811594,
#   'num_donors': 44,
#   'num_female_donors': 14,
#   'num_DA_nhoods': 3,
#   'prop_DA_nhoods': 0.08},
#  'Alveolar macrophages': {'total_samples': 68487,
#   'female_prop': 0.29280009344839164,
#   'num_donors': 84,
#   'num_female_donors': 27,
#   'num_DA_nhoods': 3428,
#   'prop_DA_nhoods': 0.71},
#  'Alveolar Mph CCL3+': {'total_samples': 8065,
#   'female_prop': 0.11134531928084315,
#   'num_donors': 60,
#   'num_female_donors': 20,
#   'num_DA_nhoods': 409,
#   'prop_DA_nhoods': 0.73},
#  'Alveolar Mph MT-positive': {'total_samples': 1203,
#   'female_prop': 0.9193682460515378,
#   'num_donors': 36,
#   'num_female_donors': 11,
#   'num_DA_nhoods': 67,
#   'prop_DA_nhoods': 0.89},
#  'Alveolar Mph proliferating': {'total_samples': 1061,
#   'female_prop': 0.35626767200754006,
#   'num_donors': 48,
#   'num_female_donors': 18,
#   'num_DA_nhoods': 22,
#   'prop_DA_nhoods': 0.29},
#  'Monocyte-derived Mph': {'total_samples': 28223,
#   'female_prop': 0.27321687984976795,
#   'num_donors': 88,
#   'num_female_donors': 30,
#   'num_DA_nhoods': 1034,
#   'prop_DA_nhoods': 0.55},
#  'Interstitial Mph perivascular': {'total_samples': 4805,
#   'female_prop': 0.17419354838709677,
#   'num_donors': 78,
#   'num_female_donors': 26,
#   'num_DA_nhoods': 124,
#   'prop_DA_nhoods': 0.41},
#  'Classical monocytes': {'total_samples': 17695,
#   'female_prop': 0.4677027408872563,
#   'num_donors': 87,
#   'num_female_donors': 29,
#   'num_DA_nhoods': 488,
#   'prop_DA_nhoods': 0.41},
#  'Non-classical monocytes': {'total_samples': 8834,
#   'female_prop': 0.26160289789449853,
#   'num_donors': 83,
#   'num_female_donors': 28,
#   'num_DA_nhoods': 245,
#   'prop_DA_nhoods': 0.42},
#  'Mast cells': {'total_samples': 6623,
#   'female_prop': 0.6022950324626303,
#   'num_donors': 81,
#   'num_female_donors': 26,
#   'num_DA_nhoods': 260,
#   'prop_DA_nhoods': 0.58}}

# %%
total_samples_dict = {cell_type: info['total_samples'] for cell_type, info in cell_type_info.items()}
df_DS['Sample counts'] = df_DS['Cell type'].map(total_samples_dict)

female_prop_dict = {cell_type: round(info['female_prop'],2) for cell_type, info in cell_type_info.items()}
df_DS['% female samples'] = df_DS['Cell type'].map(female_prop_dict)

num_donors_dict = {cell_type: info['num_donors'] for cell_type, info in cell_type_info.items()}
df_DS['# donors'] = df_DS['Cell type'].map(num_donors_dict)

num_female_donors_dict = {cell_type: info['num_female_donors'] for cell_type, info in cell_type_info.items()}
df_DS['# female donors'] = df_DS['Cell type'].map(num_female_donors_dict)

prop_DA_dict = {cell_type: info['prop_DA_nhoods'] for cell_type, info in cell_type_info.items()}
df_DS['% DA neighborhoods'] = df_DS['Cell type'].map(prop_DA_dict)

df_DS
# Out:
#                        Cell type  #DS    %DS Classification trend  \
# 0                  Basal resting  142   0.71         Inconclusive
# 1      Multiciliated (non-nasal)   42  0.208         Inconclusive
# 2           Alveolar macrophages   33  0.164             Distinct
# 3                    EC arterial   29  0.154             Distinct
# 4                     Suprabasal   19  0.094             Distinct
# ..                           ...  ...    ...                  ...
# 56    Lymphatic EC proliferating    -      -         Inconclusive
# 57  Lymphatic EC differentiating    -      -         Non-distinct
# 58        Subpleural fibroblasts    -      -             Distinct
# 59                   Mesothelium    -      -         Non-distinct
# 60      Hematopoietic stem cells    -      -         Non-distinct
#
#     Sample counts  % female samples  # donors  # female donors  \
# 0           38955              0.36        77               33
# 1           35225              0.35       102               37
# 2           68487              0.29        84               27
# 3            7391              0.21        77               25
# 4           41158              0.45        77               32
# ..            ...               ...       ...              ...
# 56             28              0.29        10                4
# 57            566              0.06        36               10
# 58            276              0.32        17                6
# 59            230              0.03        21                4
# 60             60              0.68        22               10
#
#     % DA neighborhoods
# 0                 0.58
# 1                 0.38
# 2                 0.71
# 3                 0.40
# 4                 0.67
# ..                 ...
# 56                0.00
# 57                0.52
# 58                0.68
# 59                0.93
# 60                0.00
#
# [61 rows x 9 columns]

# %%
round(df_DS.describe(),1)
# Out:
#        Sample counts  % female samples  # donors  # female donors  \
# count           61.0              61.0      61.0             61.0
# mean          9589.2               0.4      56.8             19.9
# std          14802.4               0.2      23.6              8.2
# min             28.0               0.0       9.0              4.0
# 25%            716.0               0.3      38.0             15.0
# 50%           4001.0               0.4      59.0             20.0
# 75%           9133.0               0.5      75.0             26.0
# max          68487.0               0.9     102.0             37.0
#
#        % DA neighborhoods
# count                61.0
# mean                  0.4
# std                   0.2
# min                   0.0
# 25%                   0.3
# 50%                   0.5
# 75%                   0.6
# max                   0.9

# %% [markdown]
# Final table:

# %%
df_DS.head(61)
# Out:
#                        Cell type  #DS    %DS Classification trend  \
# 0                  Basal resting  142   0.71         Inconclusive
# 1      Multiciliated (non-nasal)   42  0.208         Inconclusive
# 2           Alveolar macrophages   33  0.164             Distinct
# 3                    EC arterial   29  0.154             Distinct
# 4                     Suprabasal   19  0.094             Distinct
# ..                           ...  ...    ...                  ...
# 56    Lymphatic EC proliferating    -      -         Inconclusive
# 57  Lymphatic EC differentiating    -      -         Non-distinct
# 58        Subpleural fibroblasts    -      -             Distinct
# 59                   Mesothelium    -      -         Non-distinct
# 60      Hematopoietic stem cells    -      -         Non-distinct
#
#     Sample counts  % female samples  # donors  # female donors  \
# 0           38955              0.36        77               33
# 1           35225              0.35       102               37
# 2           68487              0.29        84               27
# 3            7391              0.21        77               25
# 4           41158              0.45        77               32
# ..            ...               ...       ...              ...
# 56             28              0.29        10                4
# 57            566              0.06        36               10
# 58            276              0.32        17                6
# 59            230              0.03        21                4
# 60             60              0.68        22               10
#
#     % DA neighborhoods
# 0                 0.58
# 1                 0.38
# 2                 0.71
# 3                 0.40
# 4                 0.67
# ..                 ...
# 56                0.00
# 57                0.52
# 58                0.68
# 59                0.93
# 60                0.00
#
# [61 rows x 9 columns]
